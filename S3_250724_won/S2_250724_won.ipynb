# %%
import os 

#folder_path = "."
#folder_path = ".."
folder_path = "../S2_250723_won"
file_list = os.listdir(folder_path)

print(file_list)
# Out:
# ['.ipynb_checkpoints', 'S2_250723_won.ipynb', 'S3_250723_won.ipynb', 'S4_250723_won.ipynb', 'S5_250723_won_복습.ipynb', 'samplesite.png']

# %%
data = "https://static.coupangcdn.com/image/retail/images/2018/09/18/11/8/6964dd11-7ff2-448d-8462-db07e3ca2a5f.jpg"

filename01 = "IMG/"+"testimg"+"."+data.split(".")[-1]
filename02 = f"IMG/testimg.{data.split(".")[-1]}"

print(filename01, filename02)
# Out:
# IMG/testimg.jpg IMG/testimg.jpg

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://davelee-fun.github.io/"
time.sleep(5)
driver.get(url)

elements = driver.find_elements(By.CSS_SELECTOR, "div.maxthumb img")
sources = []
for element in elements :
    sources.append(element.get_attribute("src"))

for index, source in enumerate(sources) :
    urlretrieve(source, f"IMG/{str(index)}.{source.split(".")[-1]}")
    


driver.quit()

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://davelee-fun.github.io/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
element = driver.find_element(By.XPATH, "//h1")

print(element.text)

    


driver.quit()
# Out:
# Teddy의 선물 블로그

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://davelee-fun.github.io/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
element = driver.find_elements(By.XPATH, "//*[@href]")

for elements in element :
    print(elements.text)


    


driver.quit()
# Out:
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 여름이불세트 관련 상품 추천
# Teddy
#
#
# 행거도어 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 행거도어 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
#
# 매트리스커버 관련 상품 추천
# Teddy
#
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# Next »
# 가구/인테리어 (90)
# Mediumish Jekyll Theme

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
element = driver.find_elements(By.XPATH, "//*[@href]")

for elements in element :
    print(elements.text)


    


driver.quit()
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
element = driver.find_elements(By.XPATH, "//a[@href]")
for elements in element :
    pattern = re.search(r"\([가-힣]{3}\)", elements.text)
    if pattern :
        print(f"✅ 매칭됨: {pattern.group()} / 전체 텍스트: {elements.text}")

    

    


driver.quit()
# Out:
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 클래스 소개
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 블로그 개발 필요한 준비물 준비하기
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 초간단 페이지 만들어보기
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 이쁘게 테마 적용해보기
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# ✅ 매칭됨: (왕초보) / 전체 텍스트: (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
element = driver.find_elements(By.XPATH, "//*[@href]")

for elements in element :
    #print(elements.text)


    
driver.quit()

# %%
#페이지네이션 실습 

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://divjason.github.io/sellenium-test/"
time.sleep(5)
driver.get(url)

#element = driver.find_element(By.XPATH, "/html/body/div/div/div/h1")
title = driver.find_elements(By.XPATH, "(//div[@class='skill-name'])[3]")



for titles in title :
    print(titles.text)
# Out:
# AI

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "(//table[last()])")
table = driver.find_elements(By.XPATH, "(//tr)[last()]")
for tables in table :
    print(tables.text)
# Out:
# 6.16 ~ 7.31 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기) 중급

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "(//table[last()])")
#table = driver.find_elements(By.XPATH, "(//tr)[2]")
table = driver.find_elements(By.XPATH, "(//tr)[position() < 2]")
for tables in table :
    print(tables.text)
# Out:
# 일정 커리큘럼 타이틀 난이도

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://divjason.github.io/sellenium-test/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "(//table[last()])")
#table = driver.find_elements(By.XPATH, "(//tr)[2]")
table = driver.find_elements(By.XPATH, "(//p[@*])")
for tables in table :
    print(tables.text)
# Out:
# 선물하기 좋은 선물을 고르고 골라서 소개하는 블로그입니다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

options.add_argument("--disable-gpu")
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "(//table[last()])")
#table = driver.find_elements(By.XPATH, "(//tr)[2]")
table = driver.find_elements(By.XPATH, "(//*[@class='course'])")
for tables in table :
    pattern2 = re.sub(r"\[\d+\]", "", tables.text)
    print(f"{pattern2}")
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

#options.add_argument("--disable-gpu")
#options.add_argument("--start-maximized")
#options.add_argument("window-size=1920x1080")
#options.add_argument("lang=ko_KR")
#options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")


driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

table = driver.find_elements(By.XPATH, "//*[contains(@class,'course')]")
for tables in table :
    pattern2 = re.sub(r"\[\d+\]", "", tables.text)
    print(f"{pattern2}")
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개
# (초급) - 필요한 프로그램 설치 시연
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

#options.add_argument("--disable-gpu")
#options.add_argument("--start-maximized")
#options.add_argument("window-size=1920x1080")
#options.add_argument("lang=ko_KR")
#options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")


driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[contains(@class,'course')]")
table = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[@class='course']")
for tables in table :
    pattern2 = re.sub(r"\[\d+\]", "", tables.text)
    print(f"{pattern2}")
# Out:
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

#options.add_argument("--disable-gpu")
#options.add_argument("--start-maximized")
#options.add_argument("window-size=1920x1080")
#options.add_argument("lang=ko_KR")
#options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")


driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

#table = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[contains(@class,'course')]")
table = driver.find_elements(By.XPATH, "//td")
for tables in table :
    print(tables.text)
# Out:
# 일정
# 커리큘럼 타이틀
# 난이도
# 5.1 ~ 6.15
# 나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT)
# 초급
# 6.16 ~ 7.31
# 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기)
# 중급

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

#options.add_argument("--disable-gpu")
#options.add_argument("--start-maximized")
#options.add_argument("window-size=1920x1080")
#options.add_argument("lang=ko_KR")
#options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")


driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
time.sleep(5)
driver.get(url)

table = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[contains(@class, 'course')]")
table = driver.find_elements(By.XPATH, "//ul[@id='dev_course_list']/*[@class='course']")
for tables in table :
    print(tables.text)
# Out:
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://crawlingtest.netlify.app/"
driver.get(url)

elements = driver.find_elements(By.XPATH, "//*[contains(@class, 'course') or contains(@class, 'maintitle')]")

for element in elements :
    print(element.text)


time.sleep(5)
driver.quit()
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://divjason.github.io/sellenium-test/"
driver.get(url)

word = driver.find_element(By.XPATH, "//span[@class='news']")
print(word.text)


time.sleep(5)
driver.quit()
# Out:
# 뉴스: 머신러닝 강좌가 나왔어요~~~

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from urllib.request import urlretrieve
import time
import re 

service = Service()
options = Options()

driver = webdriver.Chrome(service=service, options=options)
url = "https://divjason.github.io/sellenium-test/"
driver.get(url)

ID = driver.find_element(By.NAME, "username")
PW = driver.find_element(By.NAME, "password")
element = driver.find_element(By.XPATH, "//)

element.click

#word = driver.find_element(By.XPATH, "//span[@class='news']")
#print(word.text)


time.sleep(5)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[108], line 19
#      17 ID = driver.find_element(By.NAME, "username")
#      18 PW = driver.find_element(By.NAME, "password")
# ---> 19 element = driver.find_element(By.XPATH, "//*[@로그인]")
#      21 element.click
#      23 #word = driver.find_element(By.XPATH, "//span[@class='news']")
#      24 #print(word.text)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:922, in WebDriver.find_element(self, by, value)
#     919         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     920     return elements[0]
# --> 922 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
# ...
